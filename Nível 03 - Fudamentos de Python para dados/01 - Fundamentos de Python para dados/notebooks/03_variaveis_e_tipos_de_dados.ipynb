# %% [markdown]
# # **Variáveis e tipos de dados**

# %%
nome = "Bismark William"
idade = 32
altura = 1.88
salario = 1518.50

# %%
# Não iniciar o nome da variável com um número
1numero

# Não utilizar caracteres especiais (Exceção do underline)
nome*, numero)

_numero = 10

# Não utilizar espaços em branco
nome do cliente

nome_do_cliente

# %%
# Tipos de dados do Python
cliente = 'José da Silva'
type(cliente)

# %%
cliente = "Maria"
type(cliente)

# %%
idade = 32
type(idade)

# %%
altura = 1.88
type(altura)

# %%
flag = True
type(flag)
