# %% [markdown]
# # **Comentários em Python**

# %%
# Comentários de uma linha

# Serve para comentários de uma única linha
print('Olá') #comentário

# %%
# Comentários em várias linhas
# comentário1
# comentário2
# comentário3

'''
Comentários
de
várias
linhas
'''

# %%
"""
Comentários
de
várias
linhas
"""
