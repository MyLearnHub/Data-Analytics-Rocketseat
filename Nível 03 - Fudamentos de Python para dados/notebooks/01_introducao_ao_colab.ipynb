# %% [markdown]
# # **Fundamentos de Python**
#
# *Esse texto é itálico*
#
# `código`
#
# - item1
# - item2
# - item3

# %%
print("Introdução ao Google Colab")
# Out:
# Introdução ao Google Colab

# %% [markdown]
# | **Google Colab**                    | **VS Code**                                                    |
# | ----------------------------------- | -------------------------------------------------------------- |
# | Baseado em nuvem                    | Instalado localmente                                           |
# | Não requer instalação               | Requer configuração do ambiente                                |
# | Ideal para notebooks e data science | Ideal para desenvolvimento de software em geral                |
# | Acesso fácil a GPUs/TPUs            | Acesso depende da configuração do usuário                      |
# | Compartilhamento simples com links  | Compartilhamento depende de sistemas de versionamento como Git |

# %% [markdown]
# * ✔️ Organize seu notebook: use títulos e textos explicativos.
# * ✔️ Evite células muito longas: quebrem em partes menores.
# * ✔️ Documente o código: ajude quem for ler (ou você mesmo no futuro!).
# * ✔️ Sempre salve: mesmo com salvamento automático, baixe uma cópia local.
# * ✔️ Gerencie dependências: instale bibliotecas no início do notebook.
