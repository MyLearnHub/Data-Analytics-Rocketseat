# %% [markdown]
# # **Criando módulos no Colab**

# %%
import calculadora

# %%
print(f"A soma de 8 + 7 = {calculadora.soma(8, 7)}")

# %%
from calculadora import multiplicacao

# %%
print(multiplicacao(3, 4))
