# %% [markdown]
# # **Criando módulos no Google Drive**

# %%
# Montar o Drive
from google.colab import drive
drive.mount("/content/drive")

# %%
# Adicionar a pasta dos módulos
import sys
sys.path.append("/content/drive/MyDrive/meus_modulos")

# %%
import calculadora

# %%
print(calculadora.divisao(10, 5))
