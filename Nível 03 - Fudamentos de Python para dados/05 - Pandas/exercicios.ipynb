# %% [markdown]
# # 📚 Pack de Exercícios - Python Pandas
#
# Bem-vindo ao pack de exercícios! Complete cada exercício nas células de código fornecidas.
#
# ---

# %% [markdown]
# ## 📌 Tópico 1: Series
#
# Este tópico aborda criação, manipulação e operações com Series no Pandas.
#
# ---

# %% [markdown]
# ### Exercício 1.1 - Criando e Acessando Series
#
# Crie uma Series chamada `temperaturas` a partir da lista: `[22, 25, 18, 30, 27]`.
#
# Em seguida:
# 1. Exiba a Series completa
# 2. Acesse o primeiro elemento usando índice numérico
# 3. Acesse o último elemento usando índice numérico
# 4. Exiba o tipo da Series usando `type()`
# 5. Crie uma nova Series `temperaturas_nomes` com os mesmos valores, mas com índices personalizados: `['Seg', 'Ter', 'Qua', 'Qui', 'Sex']`
# 6. Acesse a temperatura de quarta-feira usando o índice personalizado
#
# **Saída esperada** (exemplos):
# ```
# 0    22
# 1    25
# 2    18
# 3    30
# 4    27
# dtype: int64
# Primeiro elemento: 22
# Último elemento: 27
# Temperatura de quarta-feira: 18
# ```
#
# **Dicas**:
# - Use `pd.Series()` para criar uma Series
# - Acesse elementos usando `serie[indice]`
# - Passe uma lista de índices como segundo parâmetro para personalizar

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 1.2 - Series a partir de Dicionário e Operações
#
# Crie uma Series chamada `vendas` a partir do dicionário:
# ```python
# {'Janeiro': 1500, 'Fevereiro': 1800, 'Março': 1200, 'Abril': 2000, 'Maio': 1700}
# ```
#
# Realize as seguintes operações:
# 1. Exiba a Series completa
# 2. Acesse as vendas de março usando o índice
# 3. Crie uma nova Series `vendas_dobradas` multiplicando todos os valores por 2
# 4. Calcule e exiba a média das vendas usando `.mean()`
# 5. Calcule e exiba a soma total usando `.sum()`
# 6. Encontre o mês com maior venda usando `.idxmax()`
# 7. Encontre o mês com menor venda usando `.idxmin()`
#
# **Saída esperada** (exemplos):
# ```
# Janeiro     1500
# Fevereiro   1800
# Março       1200
# Abril       2000
# Maio        1700
# dtype: int64
# Vendas de março: 1200
# Média das vendas: 1640.0
# Mês com maior venda: Abril
# ```
#
# **Dicas**:
# - Dicionários são convertidos automaticamente em Series com chaves como índices
# - Use métodos como `.mean()`, `.sum()`, `.idxmax()`, `.idxmin()`
# - Operações matemáticas são aplicadas elemento a elemento

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 1.3 - Operações entre Múltiplas Series
#
# Crie três Series:
# - `produto_a`: valores `[100, 120, 110, 130]` com índices `['Q1', 'Q2', 'Q3', 'Q4']`
# - `produto_b`: valores `[80, 90, 95, 100]` com índices `['Q1', 'Q2', 'Q3', 'Q4']`
# - `produto_c`: valores `[150, 140, 160, 170]` com índices `['Q1', 'Q2', 'Q3', 'Q4']`
#
# Realize as seguintes operações:
# 1. Calcule a Series `total_vendas` somando as três Series
# 2. Calcule a Series `media_trimestral` com a média dos três produtos por trimestre
# 3. Encontre o trimestre com maior venda total
# 4. Crie uma Series `diferenca_ac` com a diferença entre produto_a e produto_c
# 5. Determine em quais trimestres o produto_a superou o produto_b (retorne uma Series booleana)
# 6. Calcule o crescimento percentual do produto_a do Q1 para Q4
#
# **Saída esperada** (exemplos):
# ```
# Q1    330
# Q2    350
# Q3    365
# Q4    400
# dtype: int64
# Trimestre com maior venda: Q4
# Crescimento percentual: 30.0%
# ```
#
# **Dicas**:
# - Series com mesmos índices podem ser somadas/subtraídas diretamente
# - Use operadores de comparação para criar Series booleanas
# - Para crescimento percentual: `((final - inicial) / inicial) * 100`

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ## 📌 Tópico 2: DataFrames
#
# Este tópico aborda criação, manipulação e acesso a colunas em DataFrames.
#
# ---

# %% [markdown]
# ### Exercício 2.1 - Criando e Acessando DataFrames
#
# Crie um DataFrame chamado `funcionarios` a partir do dicionário:
# ```python
# {
#     'Nome': ['Ana', 'Bruno', 'Carla', 'Diego'],
#     'Idade': [28, 32, 25, 30],
#     'Cargo': ['Analista', 'Gerente', 'Desenvolvedor', 'Analista']
# }
# ```
#
# Em seguida:
# 1. Exiba o DataFrame completo
# 2. Exiba o tipo do DataFrame usando `type()`
# 3. Acesse a coluna 'Nome' usando notação de ponto (`df.Nome`)
# 4. Acesse a coluna 'Idade' usando notação de colchetes (`df['Idade']`)
# 5. Acesse a coluna 'Cargo' usando ambas as notações
# 6. Exiba apenas as colunas 'Nome' e 'Cargo' usando colchetes com lista
#
# **Saída esperada** (exemplos):
# ```
#     Nome  Idade        Cargo
# 0    Ana     28     Analista
# 1  Bruno     32     Gerente
# 2  Carla     25  Desenvolvedor
# 3  Diego     30     Analista
# ```
#
# **Dicas**:
# - Use `pd.DataFrame()` para criar um DataFrame
# - Notação de ponto funciona apenas se o nome da coluna não tiver espaços
# - Use `df[['col1', 'col2']]` para múltiplas colunas

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 2.2 - DataFrame a partir de Lista de Dicionários
#
# Crie um DataFrame chamado `produtos` a partir da lista de dicionários:
# ```python
# [
#     {'Produto': 'Notebook', 'Preco': 3500, 'Estoque': 15},
#     {'Produto': 'Mouse', 'Preco': 50, 'Estoque': 100},
#     {'Produto': 'Teclado', 'Preco': 200, 'Estoque': 45},
#     {'Produto': 'Monitor', 'Preco': 1200, 'Estoque': 20}
# ]
# ```
#
# Realize as seguintes operações:
# 1. Exiba o DataFrame completo
# 2. Crie uma nova coluna `Valor_Total` multiplicando 'Preco' por 'Estoque'
# 3. Acesse apenas as colunas 'Produto' e 'Valor_Total'
# 4. Crie uma nova coluna `Categoria` com o valor 'Eletrônicos' para todos os produtos
# 5. Exiba o DataFrame após todas as modificações
# 6. Verifique o número de linhas e colunas usando `.shape`
#
# **Saída esperada** (exemplos):
# ```
#     Produto  Preco  Estoque  Valor_Total    Categoria
# 0  Notebook   3500       15        52500  Eletrônicos
# 1     Mouse     50      100         5000  Eletrônicos
# ...
# Shape: (4, 5)
# ```
#
# **Dicas**:
# - Lista de dicionários também cria DataFrame automaticamente
# - Crie colunas usando `df['nova_coluna'] = valor`
# - Use `.shape` para ver dimensões (linhas, colunas)

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 2.3 - DataFrame Complexo com Múltiplas Operações
#
# Crie um DataFrame `vendas` com os seguintes dados:
# ```python
# {
#     'Vendedor': ['Alice', 'Bob', 'Charlie', 'Alice', 'Bob', 'Charlie', 'Alice'],
#     'Produto': ['A', 'B', 'A', 'C', 'A', 'B', 'C'],
#     'Quantidade': [10, 5, 8, 12, 15, 7, 9],
#     'Preco_Unitario': [100, 200, 100, 150, 100, 200, 150]
# }
# ```
#
# Realize as seguintes operações:
# 1. Crie uma coluna `Receita` = Quantidade × Preco_Unitario
# 2. Crie uma coluna `Comissao` = 5% da Receita (0.05 × Receita)
# 3. Crie uma coluna `Status` que seja 'Alta' se Receita > 1000, senão 'Normal'
# 4. Calcule a receita total por vendedor (agrupe por 'Vendedor' e some 'Receita')
# 5. Encontre o produto mais vendido (maior soma de Quantidade)
# 6. Calcule a média de receita por produto
#
# **Saída esperada** (exemplos):
# ```
# Vendedor
# Alice      3100.0
# Bob        4000.0
# Charlie    2200.0
# Name: Receita, dtype: float64
# Produto mais vendido: A
# ```
#
# **Dicas**:
# - Use operações matemáticas entre colunas
# - Use `.groupby()` para agrupar dados
# - Use condições para criar colunas baseadas em critérios

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ## 📌 Tópico 3: Leitura e Salvamento de Arquivos
#
# Este tópico aborda como ler e salvar dados em diferentes formatos.
#
# ---

# %% [markdown]
# ### Exercício 3.1 - Lendo um Arquivo CSV
#
# 1. Leia o arquivo CSV disponível em: `https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv`
# 2. Armazene os dados em um DataFrame chamado `df_mundo`
# 3. Exiba as primeiras 5 linhas usando `.head()`
# 4. Exiba as últimas 3 linhas usando `.tail()`
# 5. Verifique o número de linhas e colunas usando `.shape`
# 6. Exiba os nomes das colunas usando `.columns`
#
# **Saída esperada** (exemplos):
# ```
# Shape: (1704, 6)
# Colunas: Index(['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'], dtype='object')
# ```
#
# **Dicas**:
# - Use `pd.read_csv()` para ler arquivos CSV
# - URLs públicas podem ser lidas diretamente
# - Use `.head(n)` para ver primeiras n linhas

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 3.2 - Lendo e Salvando em Diferentes Formatos
#
# 1. Crie um DataFrame `dados` com:
# ```python
# {
#     'Cidade': ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte', 'Curitiba'],
#     'Populacao': [12300000, 6700000, 2500000, 1900000],
#     'Area_km2': [1521, 1200, 331, 435]
# }
# ```
#
# 2. Salve o DataFrame em um arquivo CSV chamado `cidades_brasil.csv` sem incluir o índice
# 3. Salve o mesmo DataFrame em um arquivo Excel chamado `cidades_brasil.xlsx` sem incluir o índice
# 4. Leia o arquivo CSV salvo em um novo DataFrame `df_csv_lido`
# 5. Leia o arquivo Excel salvo em um novo DataFrame `df_excel_lido`
# 6. Verifique se os dados foram salvos corretamente comparando os DataFrames
#
# **Saída esperada**:
# ```
# DataFrames são iguais: True
# ```
#
# **Dicas**:
# - Use `to_csv('arquivo.csv', index=False)` para salvar CSV
# - Use `to_excel('arquivo.xlsx', index=False)` para salvar Excel
# - Use `pd.read_excel()` para ler arquivos Excel
# - `index=False` evita salvar o índice

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 3.3 - Processando Múltiplos Arquivos
#
# 1. Crie três DataFrames simulando dados de vendas de diferentes meses:
#    - `vendas_jan`: {'Produto': ['A', 'B', 'C'], 'Vendas': [100, 150, 80]}
#    - `vendas_fev`: {'Produto': ['A', 'B', 'C'], 'Vendas': [120, 140, 90]}
#    - `vendas_mar`: {'Produto': ['A', 'B', 'C'], 'Vendas': [110, 160, 85]}
#
# 2. Salve cada DataFrame em arquivos CSV separados: `vendas_jan.csv`, `vendas_fev.csv`, `vendas_mar.csv`
#
# 3. Leia os três arquivos CSV em DataFrames separados
#
# 4. Adicione uma coluna 'Mes' a cada DataFrame com o mês correspondente ('Janeiro', 'Fevereiro', 'Março')
#
# 5. Combine os três DataFrames em um único DataFrame `vendas_consolidadas` usando `pd.concat()`
#
# 6. Calcule a média de vendas por produto no trimestre
#
# 7. Salve o DataFrame consolidado em `vendas_trimestre.csv`
#
# **Saída esperada** (exemplos):
# ```
# Produto
# A    110.0
# B    150.0
# C     85.0
# Name: Vendas, dtype: float64
# ```
#
# **Dicas**:
# - Use `pd.concat([df1, df2, df3])` para combinar DataFrames
# - Adicione colunas antes de concatenar para identificar a origem
# - Use `.groupby()` para calcular médias por produto

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ## 📌 Tópico 4: Exploração de Dados
#
# Este tópico aborda métodos para explorar e entender a estrutura dos dados.
#
# ---

# %% [markdown]
# ### Exercício 4.1 - Usando Head, Tail, Shape, Info e Describe
#
# Crie um DataFrame `alunos` com:
# ```python
# {
#     'Nome': ['Ana', 'Bruno', 'Carla', 'Diego', 'Eduarda', 'Fernando', 'Gabriela'],
#     'Idade': [20, 22, 21, 23, 20, 24, 22],
#     'Nota': [8.5, 7.0, 9.0, 6.5, 8.0, 7.5, 9.5],
#     'Aprovado': [True, True, True, False, True, True, True]
# }
# ```
#
# Realize as seguintes operações:
# 1. Exiba as primeiras 3 linhas usando `.head(3)`
# 2. Exiba as últimas 2 linhas usando `.tail(2)`
# 3. Verifique as dimensões usando `.shape` e exiba uma mensagem formatada
# 4. Exiba informações gerais usando `.info()`
# 5. Exiba estatísticas descritivas usando `.describe()`
#
# **Saída esperada** (exemplos):
# ```
# DataFrame tem 7 linhas e 4 colunas
# ```
#
# **Dicas**:
# - `.head(n)` mostra primeiras n linhas (padrão: 5)
# - `.tail(n)` mostra últimas n linhas (padrão: 5)
# - `.shape` retorna tupla (linhas, colunas)
# - `.describe()` mostra estatísticas apenas para colunas numéricas

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 4.2 - Análise Exploratória de Dados
#
# Leia o arquivo CSV: `https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv` e armazene em `df_exploracao`.
#
# Realize uma análise exploratória completa:
# 1. Exiba as primeiras 10 linhas
# 2. Verifique as dimensões e tipos de dados
# 3. Identifique quantos países únicos existem na coluna 'country'
# 4. Identifique quantos anos únicos existem na coluna 'year'
# 5. Verifique se há valores ausentes usando `.isna().sum()`
# 6. Exiba estatísticas descritivas das colunas numéricas
# 7. Identifique o país com maior população em todo o dataset
# 8. Identifique o país com menor expectativa de vida
#
# **Saída esperada** (exemplos):
# ```
# Países únicos: 142
# Anos únicos: 12
# País com maior população: China
# ```
#
# **Dicas**:
# - Use `.nunique()` para contar valores únicos
# - Use `.isna().sum()` para contar valores ausentes por coluna
# - Use `.idxmax()` e `.idxmin()` para encontrar índices de valores extremos

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 4.3 - Análise Exploratória Completa
#
# Crie um DataFrame `vendas_loja` com dados mais complexos:
# ```python
# {
#     'Data': pd.date_range('2023-01-01', periods=30, freq='D'),
#     'Produto': ['A']*10 + ['B']*10 + ['C']*10,
#     'Vendedor': ['V1', 'V2']*15,
#     'Quantidade': [10, 15, 8, 12, 20, 5, 18, 9, 14, 11, 25, 7, 13, 16, 6, 19, 10, 8, 15, 12, 30, 9, 11, 14, 7, 22, 13, 10, 17, 9],
#     'Preco_Unitario': [100]*10 + [150]*10 + [200]*10
# }
# ```
#
# Realize uma análise exploratória completa:
# 1. Exiba informações gerais do DataFrame
# 2. Calcule estatísticas descritivas para colunas numéricas
# 3. Identifique quantos produtos diferentes existem
# 4. Identifique quantos vendedores diferentes existem
# 5. Calcule a receita total (Quantidade × Preco_Unitario) e adicione como coluna
# 6. Identifique o dia com maior receita
# 7. Calcule a média de receita por produto
# 8. Calcule a média de receita por vendedor
# 9. Identifique padrões: qual produto tem maior quantidade média vendida?
# 10. Crie um resumo mostrando: total de vendas, receita total, receita média por dia
#
# **Saída esperada** (exemplos):
# ```
# Total de vendas: 30
# Receita total: 435000
# Receita média por dia: 14500.0
# Produto com maior quantidade média: C
# ```
#
# **Dicas**:
# - Use `pd.date_range()` para criar sequências de datas
# - Combine múltiplas análises para insights
# - Use `.groupby()` para análises por categoria

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ## 📌 Tópico 5: Seleção de Dados - Loc e Iloc
#
# Este tópico aborda métodos avançados de seleção de dados usando loc e iloc.
#
# ---

# %% [markdown]
# ### Exercício 5.1 - Seleção Básica com Loc e Iloc
#
# Crie um DataFrame `produtos` com índices personalizados:
# ```python
# df = pd.DataFrame({
#     'Produto': ['Notebook', 'Mouse', 'Teclado', 'Monitor', 'Webcam'],
#     'Preco': [3500, 50, 200, 1200, 300],
#     'Estoque': [15, 100, 45, 20, 60]
# }, index=['P001', 'P002', 'P003', 'P004', 'P005'])
# ```
#
# Realize as seguintes seleções:
# 1. Selecione a coluna 'Produto' usando `[]`
# 2. Selecione as colunas 'Produto' e 'Preco' usando `[]`
# 3. Selecione a linha com índice 'P003' usando `.loc[]`
# 4. Selecione as linhas 'P001' e 'P005' usando `.loc[]`
# 5. Selecione a terceira linha (índice 2) usando `.iloc[]`
# 6. Selecione as duas primeiras linhas usando `.iloc[]`
#
# **Saída esperada** (exemplos):
# ```
# Produto    Teclado
# Preco          200
# Estoque         45
# Name: P003, dtype: object
# ```
#
# **Dicas**:
# - `[]` seleciona colunas
# - `.loc[]` usa rótulos (nomes de índices/colunas)
# - `.iloc[]` usa posições numéricas (0-indexed)

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 5.2 - Seleções Complexas com Loc e Iloc
#
# Crie um DataFrame `vendas`:
# ```python
# df = pd.DataFrame({
#     'Vendedor': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
#     'Produto': ['A', 'B', 'A', 'C', 'B', 'A'],
#     'Quantidade': [10, 5, 8, 12, 15, 7],
#     'Preco': [100, 200, 100, 150, 200, 100]
# }, index=['V1', 'V2', 'V3', 'V4', 'V5', 'V6'])
# ```
#
# Realize as seguintes seleções:
# 1. Use `.loc[]` para selecionar linhas 'V2' e 'V5' com colunas 'Vendedor' e 'Quantidade'
# 2. Use `.iloc[]` para selecionar as linhas 1 a 3 (inclusive) e colunas 0 e 2
# 3. Use `.loc[]` com fatiamento para selecionar todas as linhas de 'V2' a 'V5' e colunas 'Produto' a 'Preco'
# 4. Use `.iloc[]` com fatiamento para selecionar as 3 primeiras linhas e 2 últimas colunas
# 5. Use `.loc[]` para selecionar apenas a coluna 'Vendedor' para todas as linhas
# 6. Use `.iloc[]` para selecionar todas as linhas e apenas a última coluna
#
# **Saída esperada** (exemplos):
# ```
#       Vendedor  Quantidade
# V2        Bob           5
# V5        Eva          15
# ```
#
# **Dicas**:
# - `.loc['V2':'V5', 'Produto':'Preco']` usa fatiamento inclusivo
# - `.iloc[1:4, 0:3]` usa fatiamento exclusivo (não inclui o último)
# - Você pode combinar seleções de linhas e colunas

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 5.3 - Seleções Avançadas com Condições
#
# Crie um DataFrame `funcionarios`:
# ```python
# df = pd.DataFrame({
#     'Nome': ['Ana', 'Bruno', 'Carla', 'Diego', 'Eduarda', 'Fernando'],
#     'Idade': [28, 32, 25, 30, 27, 35],
#     'Salario': [5000, 8000, 4500, 7000, 5500, 9000],
#     'Departamento': ['TI', 'RH', 'TI', 'Vendas', 'TI', 'Vendas']
# }, index=['F001', 'F002', 'F003', 'F004', 'F005', 'F006'])
# ```
#
# Realize seleções avançadas:
# 1. Use `.loc[]` com condição para selecionar funcionários com salário > 6000, mostrando apenas 'Nome' e 'Salario'
# 2. Use `.iloc[]` para selecionar linhas onde a idade é maior que 28 (dica: crie uma máscara booleana primeiro)
# 3. Use `.loc[]` para selecionar funcionários do departamento 'TI' com idade < 30
# 4. Use `.iloc[]` combinado com condições para selecionar as 3 primeiras colunas das linhas onde salário está entre 5000 e 7000
# 5. Crie uma seleção que mostre 'Nome', 'Idade' e 'Salario' apenas para funcionários com índice 'F002', 'F004', 'F006' usando `.loc[]`
# 6. Use `.iloc[]` para selecionar uma "janela" específica: linhas 1 a 3, colunas 0, 2 e 3
#
# **Saída esperada** (exemplos):
# ```
#      Nome  Salario
# F002  Bruno     8000
# F004  Diego     7000
# F006  Fernando  9000
# ```
#
# **Dicas**:
# - Combine `.loc[]` com condições booleanas: `df.loc[df['coluna'] > valor]`
# - Use `.iloc[]` com máscaras booleanas: `df.iloc[mascara_booleana]`
# - Você pode combinar múltiplas condições com `&` (E) e `|` (OU)

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ## 📌 Tópico 6: Filtragem de Dados
#
# Este tópico aborda como filtrar dados usando condições booleanas.
#
# ---

# %% [markdown]
# ### Exercício 6.1 - Filtros Simples
#
# Crie um DataFrame `alunos`:
# ```python
# {
#     'Nome': ['Ana', 'Bruno', 'Carla', 'Diego', 'Eduarda'],
#     'Idade': [20, 22, 21, 23, 20],
#     'Nota': [8.5, 7.0, 9.0, 6.5, 8.0]
# }
# ```
#
# Crie os seguintes filtros:
# 1. Filtre alunos com nota maior ou igual a 8.0
# 2. Filtre alunos com idade menor que 22
# 3. Filtre alunos com nota exatamente igual a 8.5
# 4. Filtre alunos com idade maior ou igual a 21
# 5. Exiba o número de alunos aprovados (nota >= 7.0) usando `len()`
#
# **Saída esperada** (exemplos):
# ```
# Alunos com nota >= 8.0:
#     Nome  Idade  Nota
# 0    Ana     20   8.5
# 2  Carla     21   9.0
# 4  Eduarda   20   8.0
#
# Número de aprovados: 4
# ```
#
# **Dicas**:
# - Use `df[df['coluna'] > valor]` para filtrar
# - Operadores: `>`, `<`, `>=`, `<=`, `==`, `!=`
# - Use `len()` para contar linhas filtradas

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 6.2 - Filtros Múltiplos com Operadores Lógicos
#
# Crie um DataFrame `produtos`:
# ```python
# {
#     'Produto': ['Notebook', 'Mouse', 'Teclado', 'Monitor', 'Webcam', 'Headset'],
#     'Preco': [3500, 50, 200, 1200, 300, 250],
#     'Categoria': ['Eletrônicos', 'Acessórios', 'Acessórios', 'Eletrônicos', 'Acessórios', 'Acessórios'],
#     'Estoque': [15, 100, 45, 20, 60, 30]
# }
# ```
#
# Crie os seguintes filtros:
# 1. Filtre produtos com preço entre 200 e 1000 (inclusive) usando operadores de comparação
# 2. Filtre produtos da categoria 'Eletrônicos' E com estoque maior que 10
# 3. Filtre produtos da categoria 'Acessórios' OU com preço menor que 100
# 4. Filtre produtos que NÃO são da categoria 'Acessórios'
# 5. Filtre produtos com preço > 1000 OU estoque < 25
# 6. Use `.isin()` para filtrar produtos com preço em [50, 200, 300]
#
# **Saída esperada** (exemplos):
# ```
# Produtos entre 200 e 1000:
#    Produto  Preco      Categoria  Estoque
# 2  Teclado    200  Acessórios        45
# 4  Webcam     300  Acessórios        60
# 5  Headset    250  Acessórios        30
# ```
#
# **Dicas**:
# - Use `&` para E (AND) - lembre-se de colocar parênteses
# - Use `|` para OU (OR) - lembre-se de colocar parênteses
# - Use `~` ou `!=` para NÃO (NOT)
# - `.isin([valores])` é útil para múltiplas condições em uma coluna

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 6.3 - Filtros Complexos e Análises
#
# Crie um DataFrame `vendas`:
# ```python
# {
#     'Vendedor': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Alice', 'Bob'],
#     'Produto': ['A', 'B', 'A', 'C', 'B', 'A', 'C', 'B'],
#     'Quantidade': [10, 5, 8, 12, 15, 7, 9, 6],
#     'Preco_Unitario': [100, 200, 100, 150, 200, 100, 150, 200],
#     'Regiao': ['Norte', 'Sul', 'Norte', 'Sul', 'Norte', 'Sul', 'Norte', 'Sul']
# }
# ```
#
# Realize análises com filtros complexos:
# 1. Calcule a receita (Quantidade × Preco_Unitario) e adicione como coluna
# 2. Filtre vendas com receita maior que 1000 E região 'Norte'
# 3. Filtre vendas onde o vendedor está em ['Alice', 'Charlie', 'Eva'] usando `.isin()`
# 4. Filtre vendas de produtos 'A' OU 'B' com quantidade >= 8
# 5. Filtre vendas que NÃO são da região 'Sul' E receita > 800
# 6. Encontre a maior receita entre vendas do produto 'A'
# 7. Calcule a média de receita por região usando filtros e agrupamento
# 8. Identifique vendedores que tiveram pelo menos uma venda com receita > 1500
#
# **Saída esperada** (exemplos):
# ```
# Maior receita produto A: 1000
# Média de receita por região:
# Regiao
# Norte    1250.0
# Sul      1200.0
# Name: Receita, dtype: float64
# ```
#
# **Dicas**:
# - Combine filtros com cálculos e agrupamentos
# - Use `.isin()` para múltiplas condições
# - Combine condições com parênteses: `(cond1) & (cond2) | (cond3)`
# - Use `.groupby()` após filtrar para análises

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ## 📌 Tópico 7: Ordenação e Tratamento de Dados
#
# Este tópico aborda ordenação de dados e tratamento de tipos e valores ausentes.
#
# ---

# %% [markdown]
# ### Exercício 7.1 - Ordenação e Conversão de Tipos Básicos
#
# Crie um DataFrame `produtos`:
# ```python
# {
#     'Produto': ['Notebook', 'Mouse', 'Teclado', 'Monitor'],
#     'Preco': ['3500', '50', '200', '1200'],  # Note: strings
#     'Quantidade': [15, 100, 45, 20]
# }
# ```
#
# Realize as seguintes operações:
# 1. Ordene o DataFrame por 'Quantidade' em ordem crescente
# 2. Ordene o DataFrame por 'Preco' em ordem decrescente (mas primeiro converta para numérico)
# 3. Converta a coluna 'Preco' de string para int usando `.astype(int)`
# 4. Após a conversão, ordene novamente por 'Preco' em ordem decrescente
# 5. Verifique os tipos de dados usando `.dtypes`
#
# **Saída esperada** (exemplos):
# ```
# Tipos após conversão:
# Produto       object
# Preco          int64
# Quantidade     int64
# dtype: object
# ```
#
# **Dicas**:
# - Use `.sort_values(by='coluna')` para ordenar
# - Use `ascending=False` para ordem decrescente
# - Use `.astype(tipo)` para converter tipos
# - Strings numéricas podem ser convertidas para int ou float

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 7.2 - Ordenação Múltipla e Tratamento de Valores Ausentes
#
# Crie um DataFrame `vendas` com valores ausentes:
# ```python
# import numpy as np
# {
#     'Vendedor': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
#     'Produto': ['A', 'B', 'A', 'C', 'B'],
#     'Quantidade': [10, np.nan, 8, 12, 15],
#     'Preco': [100, 200, np.nan, 150, 200]
# }
# ```
#
# Realize as seguintes operações:
# 1. Identifique valores ausentes usando `.isna().sum()`
# 2. Preencha valores ausentes na coluna 'Quantidade' com a média da coluna
# 3. Preencha valores ausentes na coluna 'Preco' com 0
# 4. Ordene o DataFrame por 'Vendedor' em ordem crescente, depois por 'Quantidade' em ordem decrescente
# 5. Remova linhas que ainda tenham valores ausentes (se houver) usando `.dropna()`
# 6. Verifique se ainda há valores ausentes
#
# **Saída esperada** (exemplos):
# ```
# Valores ausentes antes:
# Quantidade    1
# Preco         1
# dtype: int64
#
# Valores ausentes depois: 0
# ```
#
# **Dicas**:
# - Use `.isna()` para identificar valores ausentes
# - Use `.fillna(valor)` para preencher
# - Use `.fillna(df['coluna'].mean())` para preencher com média
# - Use `.dropna()` para remover linhas/colunas com NaN
# - Ordene por múltiplas colunas: `sort_values(by=['col1', 'col2'], ascending=[True, False])`

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 7.3 - Tratamento Completo de Dados
#
# Crie um DataFrame `dados_clientes` com dados "sujos":
# ```python
# import numpy as np
# {
#     'ID': [1, 2, 3, 4, 5, 6],
#     'Nome': ['Ana', 'Bruno', None, 'Diego', 'Eduarda', None],
#     'Idade': ['28', '32', '25', '30', None, '35'],  # Strings e None
#     'Salario': [5000, np.nan, 4500, 7000, 5500, np.nan],
#     'Categoria': ['A', 'B', 'A', None, 'B', 'A']
# }
# ```
#
# Realize um tratamento completo:
# 1. Identifique todos os valores ausentes por coluna
# 2. Converta 'Idade' para numérico (tratando strings e None)
# 3. Preencha 'Nome' ausentes com 'Desconhecido'
# 4. Preencha 'Salario' ausentes com a mediana da coluna
# 5. Preencha 'Categoria' ausentes com 'C' (categoria padrão)
# 6. Remova linhas onde 'Idade' ainda está ausente (se houver)
# 7. Ordene por 'Salario' decrescente, depois por 'Idade' crescente
# 8. Converta 'Salario' para int (após preencher)
# 9. Crie uma coluna 'Status' baseada em salário: 'Alto' se > 6000, 'Médio' se entre 4000-6000, 'Baixo' caso contrário
# 10. Exiba um resumo final: número de linhas, valores ausentes restantes, tipos de dados
#
# **Saída esperada** (exemplos):
# ```
# Linhas finais: 6
# Valores ausentes restantes: 0
# Tipos finais:
# ID           int64
# Nome        object
# Idade      float64
# Salario      int64
# Categoria   object
# Status      object
# ```
#
# **Dicas**:
# - Use `pd.to_numeric()` com `errors='coerce'` para converter strings para numérico
# - Use `.median()` para calcular mediana
# - Combine múltiplas operações de tratamento
# - Use condições para criar colunas categorizadas

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ## 📌 Tópico 8: Apply e Map
#
# Este tópico aborda aplicação de funções personalizadas usando apply e map.
#
# ---

# %% [markdown]
# ### Exercício 8.1 - Usando Map para Transformar Valores
#
# Crie um DataFrame `produtos`:
# ```python
# {
#     'Produto': ['Notebook', 'Mouse', 'Teclado', 'Monitor'],
#     'Categoria': ['Eletrônicos', 'Acessórios', 'Acessórios', 'Eletrônicos'],
#     'Status': ['ativo', 'inativo', 'ativo', 'ativo']
# }
# ```
#
# Use `.map()` para transformar valores:
# 1. Crie um dicionário de mapeamento: `{'ativo': 'Disponível', 'inativo': 'Indisponível'}`
# 2. Use `.map()` para criar uma nova coluna 'Status_Formatado' mapeando 'Status'
# 3. Crie outro mapeamento para categorias: `{'Eletrônicos': 'Eletrônico', 'Acessórios': 'Acessório'}`
# 4. Use `.map()` para criar 'Categoria_Singular'
# 5. Exiba o DataFrame com as novas colunas
#
# **Saída esperada** (exemplos):
# ```
#      Produto    Categoria Status Status_Formatado Categoria_Singular
# 0  Notebook  Eletrônicos  ativo      Disponível          Eletrônico
# 1     Mouse  Acessórios inativo   Indisponível          Acessório
# ```
#
# **Dicas**:
# - `.map()` é usado apenas em Series (colunas)
# - Passe um dicionário como argumento: `serie.map(dicionario)`
# - Valores não mapeados ficam como NaN

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 8.2 - Usando Apply com Funções Personalizadas
#
# Crie um DataFrame `funcionarios`:
# ```python
# {
#     'Nome': ['Ana', 'Bruno', 'Carla', 'Diego'],
#     'Idade': [28, 32, 25, 30],
#     'Salario': [5000, 8000, 4500, 7000]
# }
# ```
#
# Use `.apply()` para criar transformações:
# 1. Crie uma função `categoria_idade(idade)` que retorna:
#    - 'Jovem' se idade < 30
#    - 'Adulto' se idade >= 30
# 2. Use `.apply()` para criar coluna 'Categoria_Idade'
# 3. Crie uma função `calcular_bonus(salario)` que retorna 10% do salário se salário > 6000, senão 5%
# 4. Use `.apply()` para criar coluna 'Bonus'
# 5. Use `.apply()` com função lambda para criar coluna 'Salario_Anual' (salário × 12)
# 6. Crie uma função que retorna o nome em maiúsculas e use `.apply()` para criar 'Nome_Maiusculo'
#
# **Saída esperada** (exemplos):
# ```
#    Nome  Idade  Salario Categoria_Idade  Bonus  Salario_Anual Nome_Maiusculo
# 0   Ana     28     5000          Jovem    250.0          60000           ANA
# 1 Bruno     32     8000         Adulto    800.0          96000         BRUNO
# ```
#
# **Dicas**:
# - `.apply()` pode usar funções definidas ou lambda
# - Funções recebem um valor por vez (elemento da Series)
# - Use `lambda x: expressao` para funções simples

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 8.3 - Apply Avançado em Múltiplas Colunas
#
# Crie um DataFrame `vendas`:
# ```python
# {
#     'Vendedor': ['Alice', 'Bob', 'Charlie', 'David'],
#     'Quantidade': [10, 5, 8, 12],
#     'Preco_Unitario': [100, 200, 150, 120],
#     'Desconto_Percentual': [5, 10, 0, 15]
# }
# ```
#
# Realize transformações avançadas:
# 1. Use `.apply()` com lambda para calcular 'Receita_Bruta' (Quantidade × Preco_Unitario)
# 2. Crie uma função `calcular_receita_liquida(row)` que:
#    - Recebe uma linha do DataFrame (use `axis=1`)
#    - Calcula: (Quantidade × Preco_Unitario) × (1 - Desconto_Percentual/100)
#    - Retorna a receita líquida
# 3. Use `.apply()` com `axis=1` para criar coluna 'Receita_Liquida'
# 4. Crie uma função `classificar_venda(row)` que retorna:
#    - 'Alta' se Receita_Liquida > 1000
#    - 'Média' se entre 500-1000
#    - 'Baixa' caso contrário
# 5. Use `.apply()` para criar coluna 'Classificacao'
# 6. Use `.apply()` em uma coluna específica para criar 'Vendedor_Inicial' (primeira letra do nome)
# 7. Calcule a receita total usando `.sum()` na coluna 'Receita_Liquida'
#
# **Saída esperada** (exemplos):
# ```
# Receita Líquida Total: 3450.0
# ```
#
# **Dicas**:
# - Use `axis=1` em `.apply()` para processar linhas completas
# - Funções com `axis=1` recebem uma Series (linha) como parâmetro
# - Acesse valores da linha: `row['Nome_Coluna']`
# - Combine múltiplas transformações

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ## 📌 Tópico 9: Agregação e GroupBy
#
# Este tópico aborda agrupamento de dados e funções de agregação.
#
# ---

# %% [markdown]
# ### Exercício 9.1 - Agrupamento e Estatísticas Simples
#
# Crie um DataFrame `vendas`:
# ```python
# {
#     'Cidade': ['São Paulo', 'Rio de Janeiro', 'São Paulo', 'Belo Horizonte', 'Rio de Janeiro', 'São Paulo'],
#     'Produto': ['A', 'B', 'A', 'C', 'B', 'A'],
#     'Vendas': [100, 150, 120, 80, 200, 90]
# }
# ```
#
# Realize agrupamentos simples:
# 1. Agrupe por 'Cidade' e calcule a soma de 'Vendas'
# 2. Agrupe por 'Cidade' e calcule a média de 'Vendas'
# 3. Agrupe por 'Produto' e calcule a soma de 'Vendas'
# 4. Agrupe por 'Produto' e calcule a média de 'Vendas'
# 5. Agrupe por 'Cidade' e conte o número de vendas usando `.count()`
# 6. Identifique a cidade com maior soma de vendas
#
# **Saída esperada** (exemplos):
# ```
# Cidade
# Belo Horizonte     80
# Rio de Janeiro    350
# São Paulo         310
# Name: Vendas, dtype: int64
#
# Cidade com maior venda: Rio de Janeiro
# ```
#
# **Dicas**:
# - Use `.groupby('coluna')['coluna_agregar'].funcao()`
# - Funções comuns: `.sum()`, `.mean()`, `.count()`, `.max()`, `.min()`
# - O resultado é uma Series indexada pelos valores únicos da coluna de agrupamento

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 9.2 - Agrupamento Múltiplo e Múltiplas Agregações
#
# Crie um DataFrame `funcionarios`:
# ```python
# {
#     'Departamento': ['TI', 'RH', 'TI', 'Vendas', 'RH', 'Vendas', 'TI'],
#     'Cargo': ['Analista', 'Gerente', 'Desenvolvedor', 'Vendedor', 'Analista', 'Vendedor', 'Analista'],
#     'Salario': [5000, 8000, 7000, 6000, 5500, 6500, 5200],
#     'Anos_Experiencia': [2, 5, 3, 4, 2, 3, 2]
# }
# ```
#
# Realize agrupamentos avançados:
# 1. Agrupe por 'Departamento' e calcule a média de 'Salario'
# 2. Agrupe por 'Departamento' e 'Cargo', calcule a média de 'Salario'
# 3. Agrupe por 'Departamento' e calcule múltiplas estatísticas: soma de 'Anos_Experiencia' e média de 'Salario'
# 4. Use `.agg()` para calcular média, mínimo e máximo de 'Salario' por 'Departamento'
# 5. Use `.agg()` com dicionário para calcular média de 'Salario' e soma de 'Anos_Experiencia' por 'Departamento'
# 6. Agrupe por 'Cargo' e encontre o salário máximo e mínimo
#
# **Saída esperada** (exemplos):
# ```
# Departamento
# RH      6750.0
# TI      5733.333333
# Vendas  6250.0
# Name: Salario, dtype: float64
# ```
#
# **Dicas**:
# - Agrupe por múltiplas colunas: `.groupby(['col1', 'col2'])`
# - Use `.agg(['mean', 'sum'])` para múltiplas funções
# - Use `.agg({'col1': 'mean', 'col2': 'sum'})` para funções diferentes por coluna

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 9.3 - Análise Agregada Complexa
#
# Crie um DataFrame `vendas_complexas`:
# ```python
# {
#     'Data': pd.date_range('2023-01-01', periods=20, freq='D'),
#     'Vendedor': ['Alice', 'Bob'] * 10,
#     'Produto': ['A', 'B', 'A', 'C'] * 5,
#     'Regiao': ['Norte', 'Sul'] * 10,
#     'Quantidade': [10, 5, 8, 12, 15, 7, 9, 6, 11, 8, 13, 4, 10, 9, 7, 12, 14, 6, 8, 10],
#     'Preco_Unitario': [100, 200, 100, 150, 100, 200, 150, 100, 100, 200, 150, 100, 100, 200, 150, 100, 100, 200, 150, 100]
# }
# ```
#
# Realize análises agregadas complexas:
# 1. Calcule 'Receita' = Quantidade × Preco_Unitario
# 2. Agrupe por 'Vendedor' e calcule: total de vendas, receita total, receita média, maior venda única
# 3. Agrupe por 'Produto' e calcule: quantidade total vendida, receita total, média de preço unitário
# 4. Agrupe por 'Regiao' e 'Vendedor', calcule receita total e quantidade total
# 5. Agrupe por mês (extraia mês da 'Data') e calcule receita total por mês
# 6. Use `.agg()` com dicionário para calcular por 'Vendedor':
#    - Receita: ['sum', 'mean', 'max']
#    - Quantidade: ['sum', 'mean']
# 7. Encontre o vendedor com maior receita total
# 8. Encontre o produto com maior quantidade total vendida
# 9. Calcule a receita média por região
# 10. Crie um resumo mostrando: receita total geral, receita média por vendedor, produto mais vendido
#
# **Saída esperada** (exemplos):
# ```
# Receita total geral: 21000
# Vendedor com maior receita: Alice
# Produto mais vendido: A
# ```
#
# **Dicas**:
# - Use `.dt.month` para extrair mês de datas
# - Combine múltiplos agrupamentos
# - Use `.agg()` com dicionários complexos
# - Combine agrupamentos com filtros e ordenações

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ## 📌 Tópico 10: Combinação de DataFrames
#
# Este tópico aborda como combinar DataFrames usando concat, merge e join.
#
# ---

# %% [markdown]
# ### Exercício 10.1 - Concatenando DataFrames Simples
#
# Crie dois DataFrames:
# ```python
# df1 = pd.DataFrame({
#     'Produto': ['A', 'B', 'C'],
#     'Preco': [100, 200, 150]
# })
#
# df2 = pd.DataFrame({
#     'Produto': ['D', 'E', 'F'],
#     'Preco': [120, 180, 160]
# })
# ```
#
# Realize concatenações:
# 1. Concatene df1 e df2 verticalmente (por linhas) usando `pd.concat()`
# 2. Concatene com `ignore_index=True` para reindexar automaticamente
# 3. Crie df3 com colunas diferentes:
# ```python
# df3 = pd.DataFrame({
#     'Produto': ['A', 'B'],
#     'Estoque': [50, 30]
# })
# ```
# 4. Concatene df1 e df3 horizontalmente (por colunas) usando `axis=1`
# 5. Exiba os resultados de cada concatenação
#
# **Saída esperada** (exemplos):
# ```
# Concatenação vertical:
#   Produto  Preco
# 0       A    100
# 1       B    200
# 2       C    150
# 3       D    120
# 4       E    180
# 5       F    160
# ```
#
# **Dicas**:
# - `pd.concat([df1, df2])` concatena por linhas (padrão)
# - Use `axis=1` para concatenar por colunas
# - `ignore_index=True` cria novo índice numérico sequencial

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 10.2 - Merge com Diferentes Tipos
#
# Crie dois DataFrames relacionados:
# ```python
# df_clientes = pd.DataFrame({
#     'ID_Cliente': [1, 2, 3, 4],
#     'Nome': ['Alice', 'Bob', 'Charlie', 'David']
# })
#
# df_pedidos = pd.DataFrame({
#     'ID_Pedido': [101, 102, 103, 104, 105],
#     'ID_Cliente': [2, 1, 3, 2, 5],  # Cliente 5 não existe em df_clientes
#     'Produto': ['Livro', 'Caneta', 'Caderno', 'Mochila', 'Lápis'],
#     'Valor': [50, 10, 20, 80, 5]
# })
# ```
#
# Realize diferentes tipos de merge:
# 1. Faça um **inner merge** (apenas clientes com pedidos)
# 2. Faça um **left merge** (todos os clientes + pedidos se houver)
# 3. Faça um **right merge** (todos os pedidos + clientes se houver)
# 4. Faça um **outer merge** (todos os clientes e todos os pedidos)
# 5. Para cada merge, exiba o número de linhas resultantes
# 6. No left merge, identifique clientes sem pedidos (onde colunas de pedidos são NaN)
#
# **Saída esperada** (exemplos):
# ```
# Inner merge: 4 linhas
# Left merge: 4 linhas (1 cliente sem pedido)
# Right merge: 5 linhas (1 pedido sem cliente)
# Outer merge: 5 linhas
# ```
#
# **Dicas**:
# - Use `pd.merge(left, right, on='coluna', how='tipo')`
# - `inner`: apenas correspondências em ambos
# - `left`: todos do left + correspondências do right
# - `right`: todos do right + correspondências do left
# - `outer`: todos de ambos

# %%
# Seu código aqui

# %% [markdown]
# ---

# %% [markdown]
# ### Exercício 10.3 - Combinação Complexa de Múltiplos DataFrames
#
# Crie três DataFrames relacionados:
# ```python
# df_produtos = pd.DataFrame({
#     'ID_Produto': [1, 2, 3, 4],
#     'Nome': ['Notebook', 'Mouse', 'Teclado', 'Monitor'],
#     'Categoria': ['Eletrônicos', 'Acessórios', 'Acessórios', 'Eletrônicos']
# })
#
# df_vendas = pd.DataFrame({
#     'ID_Venda': [101, 102, 103, 104, 105],
#     'ID_Produto': [1, 2, 1, 3, 4],
#     'Quantidade': [5, 10, 3, 8, 2],
#     'Data': ['2023-01-15', '2023-01-16', '2023-01-17', '2023-01-18', '2023-01-19']
# })
#
# df_precos = pd.DataFrame({
#     'ID_Produto': [1, 2, 3, 4, 5],  # Produto 5 não existe em df_produtos
#     'Preco_Unitario': [3500, 50, 200, 1200, 300],
#     'Desconto': [0.1, 0.05, 0.0, 0.15, 0.1]
# })
# ```
#
# Realize combinações complexas:
# 1. Faça merge de `df_vendas` com `df_produtos` usando inner merge
# 2. Faça merge do resultado anterior com `df_precos` usando left merge
# 3. Calcule 'Receita_Bruta' = Quantidade × Preco_Unitario
# 4. Calcule 'Receita_Liquida' = Receita_Bruta × (1 - Desconto)
# 5. Crie `df_vendas_jan` e `df_vendas_fev` separando vendas por data (simule)
# 6. Concatene `df_vendas_jan` e `df_vendas_fev` verticalmente
# 7. Agrupe o DataFrame final por 'Categoria' e calcule:
#    - Receita líquida total
#    - Quantidade total vendida
#    - Número de vendas (count)
# 8. Encontre o produto com maior receita líquida
# 9. Calcule a receita média por categoria
# 10. Crie um resumo final mostrando: receita líquida total, categoria com maior receita, produto mais vendido
#
# **Saída esperada** (exemplos):
# ```
# Receita líquida total: 23450.0
# Categoria com maior receita: Eletrônicos
# Produto mais vendido: Mouse
# ```
#
# **Dicas**:
# - Combine múltiplos merges em sequência
# - Use concat para combinar dados do mesmo tipo
# - Combine merges com agrupamentos e cálculos
# - Trate valores ausentes que podem aparecer em merges

# %%
# Seu código aqui

# %% [markdown]
# ---
